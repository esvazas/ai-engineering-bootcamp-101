# %%
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct

import pandas as pd
import openai

# %%
### Let's create a dataset

qdrant_client = QdrantClient(
    url="http://localhost:6333"
)
qdrant_client.create_collection(
    collection_name='Amazon-items-collection-02',
    vectors_config=VectorParams(
        size=1536, distance=Distance.COSINE)
    )
# Out:
# True

# %%
df_items = pd.read_json("data/meta_Electronics_2022_2023_with_category_ratings_100_sample_1000.jsonl", lines=True)

def preprocess_data(row):
    return f"{row['title']} {' '.join(row['features'])}"

df_items['preprocessed_title'] = df_items.apply(preprocess_data, axis=1)
df_items['preprocessed_title'].head(2)

df_sample = df_items.sample(n=50, random_state=25)

# %%
def get_embeddings(text, model='text-embedding-3-small'):
    response = openai.embeddings.create(input=[text], model=model)
    return response.data[0].embedding


get_embeddings("Hello, world!")
# Out:
# [-0.019143931567668915,
#  -0.025292053818702698,
#  -0.0017211713129654527,
#  0.01883450709283352,
#  -0.03382139280438423,
#  -0.019682060927152634,
#  -0.02102738246321678,
#  0.05160655081272125,
#  -0.03218010067939758,
#  -0.03043118305504322,
#  -0.0021508336067199707,
#  -0.028924422338604927,
#  -0.0024871639907360077,
#  -0.03148053586483002,
#  0.010291713289916515,
#  0.01856544241309166,
#  -0.04614454507827759,
#  0.04140901193022728,
#  0.00043050304520875216,
#  0.04116685315966606,
#  0.053651440888643265,
#  0.0018481360748410225,
#  0.004564004950225353,
#  0.009955382905900478,
#  0.04781274124979973,
#  0.002164286794140935,
#  -0.00984775647521019,
#  0.038422394543886185,
#  0.0009131372789852321,
#  -0.05209086835384369,
#  0.051122233271598816,
#  -0.032529886811971664,
#  -0.01408552099019289,
#  -0.012605667114257812,
#  0.013271600939333439,
#  0.01856544241309166,
#  0.0016320437425747514,
#  -0.0008479732787236571,
#  -0.012773832306265831,
#  -0.029677802696824074,
#  -0.004510191734880209,
#  -0.015309764072299004,
#  0.02566874399781227,
#  0.009047290310263634,
#  -0.03683491423726082,
#  0.02028745599091053,
#  -0.040709443390369415,
#  -0.0026771908160299063,
#  0.03554340824484825,
#  0.0484854057431221,
#  -0.033659957349300385,
#  -0.002441759454086423,
#  0.017273934558033943,
#  0.07603760063648224,
#  0.0009543377673253417,
#  -0.04270051792263985,
#  0.00837462954223156,
#  0.07598378509283066,
#  -0.04727461561560631,
#  0.015107966028153896,
#  0.014260413125157356,
#  0.02475392445921898,
#  0.010163907893002033,
#  -0.0010005831718444824,
#  0.013729010708630085,
#  -0.010042828507721424,
#  -0.020691052079200745,
#  -0.001466400921344757,
#  -0.011704301461577415,
#  0.0493733175098896,
#  0.001116617233492434,
#  0.037857361137866974,
#  -0.019386090338230133,
#  0.005825244355946779,
#  -0.046332888305187225,
#  -0.004564004950225353,
#  -0.022359251976013184,
#  0.00879167951643467,
#  -0.026529749855399132,
#  -0.0544317252933979,
#  -0.04423418641090393,
#  0.01930537074804306,
#  -0.03094240464270115,
#  -0.06027042493224144,
#  -0.018901774659752846,
#  0.004409292712807655,
#  -0.023892918601632118,
#  -0.01195991225540638,
#  -0.01660127379000187,
#  0.0022147363051772118,
#  -0.007977759465575218,
#  0.015296311117708683,
#  0.008186284452676773,
#  0.044099655002355576,
#  -0.008926210924983025,
#  -0.0054855505004525185,
#  0.012383689172565937,
#  -0.016587819904088974,
#  -0.016466740518808365,
#  -0.024794284254312515,
#  -0.01219534408301115,
#  -0.0016606318531557918,
#  -0.004644724074751139,
#  -0.01871342957019806,
#  -0.01380300335586071,
#  0.009773763827979565,
#  0.015632640570402145,
#  -0.027350395917892456,
#  0.0006596281891688704,
#  0.03656585142016411,
#  -0.011428509838879108,
#  0.002367766574025154,
#  -0.017260480672121048,
#  -0.035328153520822525,
#  0.025843635201454163,
#  0.04054800420999527,
#  -0.006316286511719227,
#  0.0236507598310709,
#  0.022655222564935684,
#  0.025870541110634804,
#  -0.0051256767474114895,
#  -0.005287115462124348,
#  0.001331027946434915,
#  0.01466400921344757,
#  0.006016952451318502,
#  -0.0162111297249794,
#  -0.014462211169302464,
#  0.00725801195949316,
#  -0.006756879389286041,
#  -0.020933208987116814,
#  0.034547869116067886,
#  0.03979462385177612,
#  -0.0030488360207527876,
#  -0.02593780681490898,
#  -0.011253618635237217,
#  -0.02129644714295864,
#  -0.016695445403456688,
#  ...]

# %%
data_to_embed = df_sample['preprocessed_title'].tolist()

pointStructs = []

for i, text in enumerate(data_to_embed):
    embedding = get_embeddings(text)
    pointStructs.append(PointStruct(id=i, vector=embedding, payload={"text": text}))

# %%
qdrant_client.upsert(
    collection_name="Amazon-items-collection-02",
    points=pointStructs,
    wait=True
)
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
# Lets create a synthetic data

import json


batch_output_schema = {
    "type": "array",
    "items": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "Suggested question."
            },
            "chunk_ids": {
                "type": "array",
                "items": {
                    "type": "integer",
                    "description": "Index of the chunk that could be used to answer the question."
                }
            },
            "answer_example": {
                "type": "string",
                "description": "Suggested answer grounded in the context."
            },
            "reasoning": {
                "type": "string",
                "description": "Reasoning why the question could be answered with the chunks."
            }
        }
    }
}


SYSTEM_PROMPT = f"""
I am building a RAG application. I have a collection of 50 chunks of text.
The RAG application will act as a shopping assistant that can answer questions about the stock of the products we have available.
I will provide all of the available products to you with indexes of each chunk.
I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
As an output I need you to provide me the list of questions and the indexes of the chunks that could be used to answer them.
Also, provide an example answer to the question given the context of the chunks.
Also, provide the reason why you chose the chunks to answer the questions.
Try to have a mix of questions that could use multiple chunks and questions that could use single chunk.
Also, include 5 questions that can't be answered with the available chunks.

<OUTPUT JSON SCHEMA>
{json.dumps(batch_output_schema, indent=2)}
</OUTPUT JSON SCHEMA>

I need to be able to parse the json output.
"""


USER_PROMPT = f"""
Here is the list of chunks, each list element is a dictionary with id and text:
{[{"id": i, "text": data} for i, data in enumerate(data_to_embed)]}
"""

# %%
print(USER_PROMPT)
# Out:
# Here is the list of chunks, each list element is a dictionary with id and text:
# [{'id': 0, 'text': 'Bluetooth Car Adapter, LDNIO Bluetooth FM Transmitter for Car, 43W PD&QC 3.0 Three USB Port Car Bluetooth Adapter with LED Display, Hands-Free Calling, and AUX Input for All Smartphones Audio Player Fast Charging Type C Multi Ports: USB Type C Durable Fast Connect & Clear Bluetooth Sound 3 in 1 Value'}, {'id': 1, 'text': 'Bluetooth Multi-Device Keyboard, Dual Channel Universal Rechargeable Wireless Keyboard with Integrated Stand for iPad Smartphone Tablet MacBook iOS Windows Android Devices - Pink 【Easy-Switch to 2 Devices】 Simply press the FN+BT1/BT2 to switch typing between 2 connected Bluetooth devices, work with your smartphone and tablet on the slot stablely. 【Type Anywhere in Comfort】0.46in thick and 11.34in long, the compact Bluetooth keyboard is small enough to tuck into your briefcase and light enough to hold in hand. Minimalist layout lets you multitask at home or on the go. 【Precise Light-Touch Typing】Scissor-Switch circle-shape keycaps and silicone non-slip pad backside, providing you with very comfortable and pleasing typing experience, also improving your work efficiency. 【Rechargeable Battery】The bluetooth rechargeable keyboard built-in 180mAh Li-ion Battery, 2 hours full charge, above 40 hours uninterrupted work. It will automatically enter sleep mode to save power, you can press any key to wake it up. 【Wide Compatibility】 For Windows, Mac or Chrome computers, Android or iOS mobile devices. Works on iPad Air, iPad 4 / 3 / 2, iPad Mini 4, iPhone, Galaxy Tab, Macbook, Surface pro & More bluetooth enable devices.'}, {'id': 2, 'text': 'Active Noise Cancelling Wireless Earbuds, Bluetooth in-Ear Headphones Built-in 4 Mic ENC Call, Deep Bass Ear Buds,IPX6 Waterproof Stereo Earphones for iPhone,Samsung,Laptop (Blue) ♪【ANC Noise Cancelling&Game Mode】: These premium noise-canceling earbuds adopts professional audio active noise canceling technology, and the binaural microphone blocks environmental noise and enhances the voice experience. M48 wireless earbuds are built to provide the exceptional mobile gaming audio experience with an ultra-low 45ms latency.Taps 5 times to enter game mode,through quick sound effect and ideal gaming audio you never miss any game sound effects. ♪【HiFi Stereo Sound & Superior Clear Call 】: Heaphones equipped with a high-sensitivity diaphragm and dual 13mm drivers to restore audio authenticity and voice dynamics, crystal clarity and deep resonance bass characteristics enable you to enjoy immersive sound quality. Call noise canceling brings you crystal clear calls, even in a noisy environment,true wireless in-ear earbuds can achieve a perfect call experience and stereo sound. ♪【LED Light Display & USB-C Fast Charging】: Dual digital LED power display outside of the case is to show the power level for the charging case and to remind you to charge in time by USB-C charge quickly. Put wireless earphones back in the charging case, and the display will flash that meaning earbuds are being charged. 350mAH battery capacity charging case can provide 4 times full charging for two ear buds, each earphone can last for 4H, you can use it for a day without worry. ♪【Upgrade Bluetooth 5.3 & Auto Pairing & Reminder】: Adopting the latest Bluetooth technology 5.3, True wireless earbuds Bluetooth 5.3 have a faster transmission rate, lower latency, providing a fast and stable connection and signal transmission (10 meters barrier-free). Due to the replacement of old and new packaging, you may receive the package of Bluetooth 5.1, but the product is the latest version of Bluetooth 5.3, thanks for your understand. ♪【Touch Control & Transparent Mode】: Easy touch control brings you a convenient operation experience when answering calls, skipping songs, and selecting different listening modes by wireless earbuds bluetooth. With the Transprency mode, you can hear what you want to hear, so you can listen and interact with the world around you. You can clearly hear an announcement of the airline or subwa ...

# %%
print(SYSTEM_PROMPT)
# Out:
# I am building a RAG application. I have a collection of 50 chunks of text.
# The RAG application will act as a shopping assistant that can answer questions about the stock of the products we have available.
# I will provide all of the available products to you with indexes of each chunk.
# I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
# As an output I need you to provide me the list of questions and the indexes of the chunks that could be used to answer them.
# Also, provide an example answer to the question given the context of the chunks.
# Also, provide the reason why you chose the chunks to answer the questions.
# Try to have a mix of questions that could use multiple chunks and questions that could use single chunk.
# Also, include 5 questions that can't be answered with the available chunks.
#
# <OUTPUT JSON SCHEMA>
# {
#   "type": "array",
#   "items": {
#     "type": "object",
#     "properties": {
#       "question": {
#         "type": "string",
#         "description": "Suggested question."
#       },
#       "chunk_ids": {
#         "type": "array",
#         "items": {
#           "type": "integer",
#           "description": "Index of the chunk that could be used to answer the question."
#         }
#       },
#       "answer_example": {
#         "type": "string",
#         "description": "Suggested answer grounded in the context."
#       },
#       "reasoning": {
#         "type": "string",
#         "description": "Reasoning why the question could be answered with the chunks."
#       }
#     }
#   }
# }
# </OUTPUT JSON SCHEMA>
#
# I need to be able to parse the json output.

# %%
response = openai.chat.completions.create(
    model='gpt-4.1',
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": USER_PROMPT}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# ```json
# [
#   {
#     "question": "Which products are available for wireless Bluetooth audio playback?",
#     "chunk_ids": [0,2,5,9,23,47,49],
#     "answer_example": "We have the following products that support wireless Bluetooth audio playback: Bluetooth Car Adapter (id:0), Active Noise Cancelling Wireless Earbuds (id:2), Glorious Model D Wireless Gaming Mouse (id:5, note: it's a mouse, not an audio device but mentions Bluetooth), maio Bluetooth Speaker (id:9), Tiksounds Wireless Earbuds (id:47), Razer Leviathan V2 X PC Soundbar (id:49), and the co2CREA Soft Silicone Case (id:23, case for Bose Bluetooth speaker - actual speaker sold separately).",
#     "reasoning": "These chunks mention Bluetooth-enabled audio devices like speakers, earbuds, and adapters, as well as cases for Bluetooth speakers."
#   },
#   {
#     "question": "Do you have any accessories compatible with iPhone 14?",
#     "chunk_ids": [13,22,26,39],
#     "answer_example": "Yes, we have several accessories compatible with iPhone 14, including a CarPlay USB A to Lightning Cable (id:13), Apple Earbuds with Lightning Connector (id:22), MFi certified Lightning Cable (id:26), and a Lightning to 3.5 mm Headphone Jack Adapter (id:39).",
#     "reasoning": "Each chunk specifically mentions compatibility with iPhone 14."
#   },
#   {
#     "question": "What gaming mice do you currently have in stock?",
#     "chunk_ids": [5],
#     "answer_example": "We have the Glorious Model D Wireless Gaming Mouse (id:5) in stock. It features RGB lighting, an ergonomic design, a honeycomb shell, superlight weight (69g), and both wired and wireless modes.",
#     "reasoning": "Only chunk 5 lists a gaming mouse."
#   },
#   {
#     "question": "Which products help with cable or wire management?",
#     "chunk_ids": [4,17,43,36],
#     "answer_example": "For cable and wire management, we have tifanso Cable Clips (id:4), 40-piece Silicone Cable Ties (id:17), ApexOne Reusable Hook and Loop Straps (id:43), and a 4-Port USB Hub (id:36) for connecting multiple USB devices.",
#     "reasoning": "Chunks include descriptions of cable clips, cable ties, hook-and-loop straps, and a USB hub for wire organization."
#   },
#   {
#     "question": "Are there any multi-device Bluetooth keyboards available?",
#     "chunk_ids": [1,25,28],
#     "answer_example": "Yes, we offer multiple multi-device Bluetooth keyboards: Bluetooth Multi-Device Keyboard with stand (id:1), Nasuque Bluetooth Keyboard for Mac OS (id:25), and the Samsers Ultra Slim Rechargeable Dual-Mode Keyboard and Mouse Combo (id:28).",
#     "reasoning": "These chunks describe keyboards capable of connecting to multiple devices via Bluetooth."
#   },
#   {
#     "question": "Which external storage devices do you have for data transfer?",
#     "chunk_ids": [6,44,37],
#     "answer_example": "External storage devices available include the LinkMore NR34 128GB USB 3.1 Flash Drive (id:6), ALLBYT iPhone Flash Drive 1TB (id:44), and a 3-pack USB2.0 SD Card Reader (id:37).",
#     "reasoning": "Chunks describe USB flash drives and card readers for data transfer between devices."
#   },
#   {
#     "question": "Do you stock any smartwatches with health monitoring features?",
#     "chunk_ids": [15],
#     "answer_example": "We have the CHOKOVIE Smart Watch (id:15), which features health monitoring such as heart rate, blood oxygen, step counting, and sleep analysis.",
#     "reasoning": "Chunk 15 is about a smartwatch with explicit health and fitness features."
#   },
#   {
#     "question": "Are there any security cameras featuring night vision?",
#     "chunk_ids": [3,30],
#     "answer_example": "Yes, we stock security cameras with night vision. The Noonkey 2K/3MP Light Bulb Security Camera (id:3) offers color night vision modes, and the VAIMEST Security Cameras Wireless Outdoor (id:30) features color night vision with floodlights.",
#     "reasoning": "Both chunks mention night vision features for home security cameras."
#   },
#   {
#     "question": "Do you have any waterproof audio devices?",
#     "chunk_ids": [2,9,47],
#     "answer_example": "We have waterproof audio devices such as the ANC Wireless Earbuds (id:2, IPX6), maio Bluetooth Speaker (id:9, IPX67), and Tiksounds Wireless Earbuds (id:47, IPX7).",
#     "reasoning": "Each chunk states a relevant IPX waterproof rating."
#   },
#   {
#     "question": "Which products are suitable for children?",
#     "chunk_ids": [20,41,21],
#     "answer_example": "Products suitable for children include the YIMIKOL Kids Shockproof iPad Case (id:20), Fullant 7-inch Kids Android Tablet (id:41), and Aroncent Portable Binoculars (id:21).",
#     "reasoning": "Products are specifically designed for children, with safety, durability, and/or educational value."
#   },
#   {
#     "question": "Are there any camera accessories compatible with DJI Mini 3 drones?",
#     "chunk_ids": [14],
#     "answer_example": "Yes, we have the NEEWER ND Filter Set (id:14), which is compatible with DJI Mini 3/Mini 3 Pro drones.",
#     "reasoning": "Chunk 14 is the only product for DJI Mini 3 accessories."
#   },
#   {
#     "question": "Do you carry any replacement wristbands for smartwatches or fitness trackers?",
#     "chunk_ids": [8,18],
#     "answer_example": "Yes, we offer YAXIN Slim Sport Bands compatible with Fitbit Versa models (id:8), and NotoCity 22mm bands for Fenix and Forerunner smartwatches (id:18).",
#     "reasoning": "Both chunks mention watch replacement bands for specific smartwatch models."
#   },
#   {
#     "question": "Which products can be used with Apple CarPlay?",
#     "chunk_ids": [12,13,29],
#     "answer_example": "We have a Double Din Car Stereo with Wireless CarPlay (id:12), a USB A to Lightning CarPlay Cable (id:13), and a Wireless CarPlay Adapter for compatible cars (id:29).",
#     "reasoning": "All these products mention explicit support for Apple CarPlay."
#   },
#   {
#     "question": "Are there any products for organizing or protecting laptops?",
#     "chunk_ids": [24,35],
#     "answer_example": "You can organize or protect your laptop with the ECOSUSI Briefcase Messenger Backpack (id:24) and the NISHEL Laptop Sleeve Case for 13-13.3 inch laptops (id:35).",
#     "reasoning": "Briefcase and sleeve case both suitable for laptop protection."
#   },
#   {
#     "question": "Which products support both Android and iOS platforms?",
#     "chunk_ids": [1,19,44,38,41],
#     "answer_example": "Products supporting both Android and iOS include the Bluetooth Multi-Device Keyboard (id:1), SKYBASIC Wireless Digital Microscope (id:19), ALLBYT iPhone Flash Drive (id:44), GPS Tracker for Dogs/Kids (id:38), and Fullant Kids Tablet (id:41).",
#     "reasoning": "Each product specifically lists Android and iOS compatibility."
#   },
#   {
#     "question": "Do you offer any photographic lights or accessories for content creators?",
#     "chunk_ids": [40],
#     "answer_example": "Yes, we have a 10'' Ring Light with Tripod Stand & Phone Holder (id:40), ideal for TikTok, YouTube, selfies, and ambient lighting for content creation.",
#     "reasoning": "Chunk 40 describes a photographic ring light for video/selfie use."
#   },
#   {
#     "question": "Can I purchase any devices for music playback via both Bluetooth and wired connections?",
#     "chunk_ids": [9,49,33],
#     "answer_example": "Yes, the maio Bluetooth Speaker (id:9) supports both Bluetooth and Aux-in, the Razer Leviathan V2 X PC Soundbar (id:49) supports USB and Bluetooth, and RGB Gaming Desktop Speakers (id:33) support both USB audio and Bluetooth connections.",
#     "reasoning": "These devices offer multiple audio input methods."
#   },
#   {
#     "question": "Do you sell any device mounts or stands for organizing tech gadgets?",
#     "chunk_ids": [7,45],
#     "answer_example": "Yes, we have an Owl Holder Stand for Echo Dot and Google Nest Mini (id:7) and a Bulletpoint Metal 4-Hole AMPS Base Mount for devices (id:45).",
#     "reasoning": "Both products are mounts/stands for tech gadgets."
#   },
#   {
#     "question": "Is there a USB hub available for connecting multiple devices to my computer?",
#     "chunk_ids": [36],
#     "answer_example": "Yes, the barsone 4 Port USB Hub 3.0 (id:36) allows you to connect up to four USB devices to your computer.",
#     "reasoning": "Only chunk 36 is a USB hub."
#   },
#   {
#     "question": "Do you have any headsets or earbuds that support active noise cancellation?",
#     "chunk_ids": [2],
#     "answer_example": "Yes, our Active Noise Cancelling Wireless Earbuds (id:2) offer ANC and ENC noise reduction for clear calls and immersive audio.",
#     "reasoning": "Only chunk 2 specifically mentions active noise cancellation."
#   },
#   {
#     "question": "Are there any outlet extenders or surge protectors available?",
#     "chunk_ids": [32],
#     "answer_example": "Yes, we have a 5 Outlet Surge Protector Power Strip with USB Ports and LED Night Light (id:32).",
#     "reasoning": "Only chunk 32 describes an outlet extender with surge protection."
#   },
#   {
#     "question": "Do you offer any specialized computer monitors?",
#     "chunk_ids": [42],
#     "answer_example": "We have the LG UltraWide FHD 26-Inch Computer Monitor (id:42) with 21:9 resolution, HDR10, and AMD FreeSync support.",
#     "reasoning": "Chunk 42 describes a specialized ultra-wide computer monitor."
#   },
#   {
#     "question": "Are there any devices for offline navigation or cycling activity tracking?",
#     "chunk_ids": [48],
#     "answer_example": "Yes, we offer the Garmin Edge Explore 2 GPS Cycling Navigator (id:48), which features preloaded maps, ride tracking, and various cycling activity profiles.",
#     "reasoning": "Only chunk 48 describes a GPS cycling navigator."
#   },
#   {
#     "question": "Which products aid with home or vehicle safety?",
#     "chunk_ids": [3,30,31],
#     "answer_example": "For safety, we offer Noonkey WiFi Light Bulb Security Cameras (id:3), VAIMEST Wireless Outdoor Security Camera (id:30), and the Esky License Plate Backup Camera (id:31) for vehicles.",
#     "reasoning": "These chunks describe cameras for home security and vehicle safety."
#   },
#   {
#     "question": "Do you have any wireless or rechargeable mouse and keyboard combos?",
#     "chunk_ids": [28],
#     "answer_example": "Yes, the Samsers Ultra Slim Rechargeable Wireless Keyboard and Mouse Combo (id:28) offers dual-mode Bluetooth and 2.4G connectivity, and is rechargeable.",
#     "reasoning": "Only chunk 28 specifically describes a wireless keyboard and mouse combo."
#   },
#   {
#     "question": "Are there any products for digitizing or recording vinyl records?",
#     "chunk_ids": [46],
#     "answer_example": "Yes, the Vinyl Record Player Turntable with Speakers (id:46) supports vinyl-to-MP3 USB recording.",
#     "reasoning": "Chunk 46 mentions USB recording from vinyl playback."
#   },
#   {
#     "question": "Do you have any Arduino-compatible or STEM education kits?",
#     "chunk_ids": [34],
#     "answer_example": "Yes, we offer the SunFounder Ultimate Starter Kit compatible with Arduino UNO IDE, with 192 items and 87 projects for all skill levels (id:34).",
#     "reasoning": "Chunk 34 describes a STEM starter kit for Arduino."
#   },
#   {
#     "question": "Can I get a replacement case or protective cover for a Bose SoundLink Flex Bluetooth Speaker?",
#     "chunk_ids": [23],
#     "answer_example": "Yes, we have the co2CREA Soft Silicone Case Replacement for the Bose SoundLink Flex Bluetooth Portable Speaker (id:23).",
#     "reasoning": "Chunk 23 mentions a specific Bose speaker case."
#   },
#   {
#     "question": "Are there any GPS tracker tags for pets or belongings?",
#     "chunk_ids": [38],
#     "answer_example": "Yes, we offer an 8-Pack GPS Tracker for Dogs, Kids, and belongings (id:38).",
#     "reasoning": "Only chunk 38 is about GPS tracker tags."
#   },
#   {
#     "question": "Do you sell any 3D model building kits for hobbies?",
#     "chunk_ids": [27],
#     "answer_example": "We have the BANDAI SPIRITS #44 Cyclase's Schwalbe Custom Iron-Blooded Orphans 1/144 Model Building Kit (id:27).",
#     "reasoning": "Chunk 27 describes a hobby model kit."
#   },
#   {
#     "question": "Can you tell me which laptops or computers you have available for sale?",
#     "chunk_ids": [],
#     "answer_example": "I'm sorry, but we do not currently have any laptops or computers available for sale.",
#     "reasoning": "None of the chunks describe actual laptops or computers for sale, only accessories."
#   },
#   {
#     "question": "Are there any televisions or smart TVs in stock?",
#     "chunk_ids": [],
#     "answer_example": "We do not currently stock any televisions or smart TVs.",
#     "reasoning": "No TV or smart TV products described in any chunk."
#   },
#   {
#     "question": "Do you carry any kitchen appliances, such as toasters or blenders?",
#     "chunk_ids": [],
#     "answer_example": "We do not have any kitchen appliances like toasters or blenders in stock.",
#     "reasoning": "No chunk references kitchen appliances."
#   },
#   {
#     "question": "Are there any textbooks or printed novels available?",
#     "chunk_ids": [],
#     "answer_example": "Currently, we do not have textbooks or printed novels for sale.",
#     "reasoning": "No books are mentioned in the provided chunks."
#   },
#   {
#     "question": "Can I order any clothing or footwear items?",
#     "chunk_ids": [],
#     "answer_example": "We do not currently offer clothing or footwear for purchase.",
#     "reasoning": "No clothing or footwear products appear in any chunk."
#   }
# ]
# ```

# %%
import json

json_output = response.choices[0].message.content
json_output = json_output.replace("```json", "")
json_output = json_output.replace("```", "")
json_output = json.loads(json_output)

# %%
json_output
# Out:
# [{'question': 'Which products are available for wireless Bluetooth audio playback?',
#   'chunk_ids': [0, 2, 5, 9, 23, 47, 49],
#   'answer_example': "We have the following products that support wireless Bluetooth audio playback: Bluetooth Car Adapter (id:0), Active Noise Cancelling Wireless Earbuds (id:2), Glorious Model D Wireless Gaming Mouse (id:5, note: it's a mouse, not an audio device but mentions Bluetooth), maio Bluetooth Speaker (id:9), Tiksounds Wireless Earbuds (id:47), Razer Leviathan V2 X PC Soundbar (id:49), and the co2CREA Soft Silicone Case (id:23, case for Bose Bluetooth speaker - actual speaker sold separately).",
#   'reasoning': 'These chunks mention Bluetooth-enabled audio devices like speakers, earbuds, and adapters, as well as cases for Bluetooth speakers.'},
#  {'question': 'Do you have any accessories compatible with iPhone 14?',
#   'chunk_ids': [13, 22, 26, 39],
#   'answer_example': 'Yes, we have several accessories compatible with iPhone 14, including a CarPlay USB A to Lightning Cable (id:13), Apple Earbuds with Lightning Connector (id:22), MFi certified Lightning Cable (id:26), and a Lightning to 3.5 mm Headphone Jack Adapter (id:39).',
#   'reasoning': 'Each chunk specifically mentions compatibility with iPhone 14.'},
#  {'question': 'What gaming mice do you currently have in stock?',
#   'chunk_ids': [5],
#   'answer_example': 'We have the Glorious Model D Wireless Gaming Mouse (id:5) in stock. It features RGB lighting, an ergonomic design, a honeycomb shell, superlight weight (69g), and both wired and wireless modes.',
#   'reasoning': 'Only chunk 5 lists a gaming mouse.'},
#  {'question': 'Which products help with cable or wire management?',
#   'chunk_ids': [4, 17, 43, 36],
#   'answer_example': 'For cable and wire management, we have tifanso Cable Clips (id:4), 40-piece Silicone Cable Ties (id:17), ApexOne Reusable Hook and Loop Straps (id:43), and a 4-Port USB Hub (id:36) for connecting multiple USB devices.',
#   'reasoning': 'Chunks include descriptions of cable clips, cable ties, hook-and-loop straps, and a USB hub for wire organization.'},
#  {'question': 'Are there any multi-device Bluetooth keyboards available?',
#   'chunk_ids': [1, 25, 28],
#   'answer_example': 'Yes, we offer multiple multi-device Bluetooth keyboards: Bluetooth Multi-Device Keyboard with stand (id:1), Nasuque Bluetooth Keyboard for Mac OS (id:25), and the Samsers Ultra Slim Rechargeable Dual-Mode Keyboard and Mouse Combo (id:28).',
#   'reasoning': 'These chunks describe keyboards capable of connecting to multiple devices via Bluetooth.'},
#  {'question': 'Which external storage devices do you have for data transfer?',
#   'chunk_ids': [6, 44, 37],
#   'answer_example': 'External storage devices available include the LinkMore NR34 128GB USB 3.1 Flash Drive (id:6), ALLBYT iPhone Flash Drive 1TB (id:44), and a 3-pack USB2.0 SD Card Reader (id:37).',
#   'reasoning': 'Chunks describe USB flash drives and card readers for data transfer between devices.'},
#  {'question': 'Do you stock any smartwatches with health monitoring features?',
#   'chunk_ids': [15],
#   'answer_example': 'We have the CHOKOVIE Smart Watch (id:15), which features health monitoring such as heart rate, blood oxygen, step counting, and sleep analysis.',
#   'reasoning': 'Chunk 15 is about a smartwatch with explicit health and fitness features.'},
#  {'question': 'Are there any security cameras featuring night vision?',
#   'chunk_ids': [3, 30],
#   'answer_example': 'Yes, we stock security cameras with night vision. The Noonkey 2K/3MP Light Bulb Security Camera (id:3) offers color night vision modes, and the VAIMEST Security Cameras Wireless Outdoor (id:30) features color night vision with floodlights.',
#   'reasoning': 'Both chunks mention night vision features for home security cameras.'},
#  {'question': 'Do you have any waterproof audio devices?',
#   'chunk_ids': [2, 9, 47],
#   'answer_example': 'We have waterproof audio devices such as the ANC Wireless Earbuds (id:2, IPX6), maio Bluetooth Speaker (id:9, IPX67), and Tiksounds Wireless Earbuds (id:47, IPX7).',
#   'reasoning': 'Each chunk states a relevant IPX waterproof rating.'},
#  {'question': 'Which products are suitable for children?',
#   'chunk_ids': [20, 41, 21],
#   'answer_example': 'Products suitable for children include the YIMIKOL Kids Shockproof iPad Case (id:20), Fullant 7-inch Kids Android Tablet (id:41), and Aroncent Portable Binoculars (id:21).',
#   'reasoning': 'Products are specifically designed for children, with safety, durability, and/or educational value.'},
#  {'question': 'Are there any camera accessories compatible with DJI Mini 3 drones?',
#   'chunk_ids': [14],
#   'answer_example': 'Yes, we have the NEEWER ND Filter Set (id:14), which is compatible with DJI Mini 3/Mini 3 Pro drones.',
#   'reasoning': 'Chunk 14 is the only product for DJI Mini 3 accessories.'},
#  {'question': 'Do you carry any replacement wristbands for smartwatches or fitness trackers?',
#   'chunk_ids': [8, 18],
#   'answer_example': 'Yes, we offer YAXIN Slim Sport Bands compatible with Fitbit Versa models (id:8), and NotoCity 22mm bands for Fenix and Forerunner smartwatches (id:18).',
#   'reasoning': 'Both chunks mention watch replacement bands for specific smartwatch models.'},
#  {'question': 'Which products can be used with Apple CarPlay?',
#   'chunk_ids': [12, 13, 29],
#   'answer_example': 'We have a Double Din Car Stereo with Wireless CarPlay (id:12), a USB A to Lightning CarPlay Cable (id:13), and a Wireless CarPlay Adapter for compatible cars (id:29).',
#   'reasoning': 'All these products mention explicit support for Apple CarPlay.'},
#  {'question': 'Are there any products for organizing or protecting laptops?',
#   'chunk_ids': [24, 35],
#   'answer_example': 'You can organize or protect your laptop with the ECOSUSI Briefcase Messenger Backpack (id:24) and the NISHEL Laptop Sleeve Case for 13-13.3 inch laptops (id:35).',
#   'reasoning': 'Briefcase and sleeve case both suitable for laptop protection.'},
#  {'question': 'Which products support both Android and iOS platforms?',
#   'chunk_ids': [1, 19, 44, 38, 41],
#   'answer_example': 'Products supporting both Android and iOS include the Bluetooth Multi-Device Keyboard (id:1), SKYBASIC Wireless Digital Microscope (id:19), ALLBYT iPhone Flash Drive (id:44), GPS Tracker for Dogs/Kids (id:38), and Fullant Kids Tablet (id:41).',
#   'reasoning': 'Each product specifically lists Android and iOS compatibility.'},
#  {'question': 'Do you offer any photographic lights or accessories for content creators?',
#   'chunk_ids': [40],
#   'answer_example': "Yes, we have a 10'' Ring Light with Tripod Stand & Phone Holder (id:40), ideal for TikTok, YouTube, selfies, and ambient lighting for content creation.",
#   'reasoning': 'Chunk 40 describes a photographic ring light for video/selfie use.'},
#  {'question': 'Can I purchase any devices for music playback via both Bluetooth and wired connections?',
#   'chunk_ids': [9, 49, 33],
#   'answer_example': 'Yes, the maio Bluetooth Speaker (id:9) supports both Bluetooth and Aux-in, the Razer Leviathan V2 X PC Soundbar (id:49) supports USB and Bluetooth, and RGB Gaming Desktop Speakers (id:33) support both USB audio and Bluetooth connections.',
#   'reasoning': 'These devices offer multiple audio input methods.'},
#  {'question': 'Do you sell any device mounts or stands for organizing tech gadgets?',
#   'chunk_ids': [7, 45],
#   'answer_example': 'Yes, we have an Owl Holder Stand for Echo Dot and Google Nest Mini (id:7) and a Bulletpoint Metal 4-Hole AMPS Base Mount for devices (id:45).',
#   'reasoning': 'Both products are mounts/stands for tech gadgets.'},
#  {'question': 'Is there a USB hub available for connecting multiple devices to my computer?',
#   'chunk_ids': [36],
#   'answer_example': 'Yes, the barsone 4 Port USB Hub 3.0 (id:36) allows you to connect up to four USB devices to your computer.',
#   'reasoning': 'Only chunk 36 is a USB hub.'},
#  {'question': 'Do you have any headsets or earbuds that support active noise cancellation?',
#   'chunk_ids': [2],
#   'answer_example': 'Yes, our Active Noise Cancelling Wireless Earbuds (id:2) offer ANC and ENC noise reduction for clear calls and immersive audio.',
#   'reasoning': 'Only chunk 2 specifically mentions active noise cancellation.'},
#  {'question': 'Are there any outlet extenders or surge protectors available?',
#   'chunk_ids': [32],
#   'answer_example': 'Yes, we have a 5 Outlet Surge Protector Power Strip with USB Ports and LED Night Light (id:32).',
#   'reasoning': 'Only chunk 32 describes an outlet extender with surge protection.'},
#  {'question': 'Do you offer any specialized computer monitors?',
#   'chunk_ids': [42],
#   'answer_example': 'We have the LG UltraWide FHD 26-Inch Computer Monitor (id:42) with 21:9 resolution, HDR10, and AMD FreeSync support.',
#   'reasoning': 'Chunk 42 describes a specialized ultra-wide computer monitor.'},
#  {'question': 'Are there any devices for offline navigation or cycling activity tracking?',
#   'chunk_ids': [48],
#   'answer_example': 'Yes, we offer the Garmin Edge Explore 2 GPS Cycling Navigator (id:48), which features preloaded maps, ride tracking, and various cycling activity profiles.',
#   'reasoning': 'Only chunk 48 describes a GPS cycling navigator.'},
#  {'question': 'Which products aid with home or vehicle safety?',
#   'chunk_ids': [3, 30, 31],
#   'answer_example': 'For safety, we offer Noonkey WiFi Light Bulb Security Cameras (id:3), VAIMEST Wireless Outdoor Security Camera (id:30), and the Esky License Plate Backup Camera (id:31) for vehicles.',
#   'reasoning': 'These chunks describe cameras for home security and vehicle safety.'},
#  {'question': 'Do you have any wireless or rechargeable mouse and keyboard combos?',
#   'chunk_ids': [28],
#   'answer_example': 'Yes, the Samsers Ultra Slim Rechargeable Wireless Keyboard and Mouse Combo (id:28) offers dual-mode Bluetooth and 2.4G connectivity, and is rechargeable.',
#   'reasoning': 'Only chunk 28 specifically describes a wireless keyboard and mouse combo.'},
#  {'question': 'Are there any products for digitizing or recording vinyl records?',
#   'chunk_ids': [46],
#   'answer_example': 'Yes, the Vinyl Record Player Turntable with Speakers (id:46) supports vinyl-to-MP3 USB recording.',
#   'reasoning': 'Chunk 46 mentions USB recording from vinyl playback.'},
#  {'question': 'Do you have any Arduino-compatible or STEM education kits?',
#   'chunk_ids': [34],
#   'answer_example': 'Yes, we offer the SunFounder Ultimate Starter Kit compatible with Arduino UNO IDE, with 192 items and 87 projects for all skill levels (id:34).',
#   'reasoning': 'Chunk 34 describes a STEM starter kit for Arduino.'},
#  {'question': 'Can I get a replacement case or protective cover for a Bose SoundLink Flex Bluetooth Speaker?',
#   'chunk_ids': [23],
#   'answer_example': 'Yes, we have the co2CREA Soft Silicone Case Replacement for the Bose SoundLink Flex Bluetooth Portable Speaker (id:23).',
#   'reasoning': 'Chunk 23 mentions a specific Bose speaker case.'},
#  {'question': 'Are there any GPS tracker tags for pets or belongings?',
#   'chunk_ids': [38],
#   'answer_example': 'Yes, we offer an 8-Pack GPS Tracker for Dogs, Kids, and belongings (id:38).',
#   'reasoning': 'Only chunk 38 is about GPS tracker tags.'},
#  {'question': 'Do you sell any 3D model building kits for hobbies?',
#   'chunk_ids': [27],
#   'answer_example': "We have the BANDAI SPIRITS #44 Cyclase's Schwalbe Custom Iron-Blooded Orphans 1/144 Model Building Kit (id:27).",
#   'reasoning': 'Chunk 27 describes a hobby model kit.'},
#  {'question': 'Can you tell me which laptops or computers you have available for sale?',
#   'chunk_ids': [],
#   'answer_example': "I'm sorry, but we do not currently have any laptops or computers available for sale.",
#   'reasoning': 'None of the chunks describe actual laptops or computers for sale, only accessories.'},
#  {'question': 'Are there any televisions or smart TVs in stock?',
#   'chunk_ids': [],
#   'answer_example': 'We do not currently stock any televisions or smart TVs.',
#   'reasoning': 'No TV or smart TV products described in any chunk.'},
#  {'question': 'Do you carry any kitchen appliances, such as toasters or blenders?',
#   'chunk_ids': [],
#   'answer_example': 'We do not have any kitchen appliances like toasters or blenders in stock.',
#   'reasoning': 'No chunk references kitchen appliances.'},
#  {'question': 'Are there any textbooks or printed novels available?',
#   'chunk_ids': [],
#   'answer_example': 'Currently, we do not have textbooks or printed novels for sale.',
#   'reasoning': 'No books are mentioned in the provided chunks.'},
#  {'question': 'Can I order any clothing or footwear items?',
#   'chunk_ids': [],
#   'answer_example': 'We do not currently offer clothing or footwear for purchase.',
#   'reasoning': 'No clothing or footwear products appear in any chunk.'}]

# %%
from langsmith import Client
import os

client = Client(api_key=os.environ['LANGSMITH_API_KEY'])
dataset_name = "rag-evaluation-dataset"
dataset = client.create_dataset(
    dataset_name=dataset_name,
    description='Dataset for evaluating RAG pipeline'
)

# %%
for item in json_output:
    client.create_example(
        dataset_id=dataset.id,
        inputs={"question": item["question"]},
        outputs={
            "ground_truth": item["answer_example"],
            "context_ids": item["chunk_ids"],
            "contexts": [
                qdrant_client.retrieve(collection_name="Amazon-items-collection-02", ids=[id], with_payload=True)[0].payload["text"]
                for id in item["chunk_ids"]
            ]
        }
    )
